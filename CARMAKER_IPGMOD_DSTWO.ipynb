# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam1494/Autonomous-Lane-Keeping/blob/main/CARMAKER_IPGMOD_DSTWO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KAGGLE

# %%
#Upload json kaggle
# %%capture
# !pip install kaggle
# !mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d shyamsundaravce/ipg-carmaker
# Out:
# Downloading ipg-carmaker.zip to /content
# 100% 1.74G/1.74G [01:39<00:00, 23.1MB/s]
# 100% 1.74G/1.74G [01:39<00:00, 18.8MB/s]

# %%
# %%capture
# !unzip  /content/ipg-carmaker.zip

# %% [markdown]
# # LIBRARIES INSTALLED

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import csv
import os

# %%
df = pd.read_csv('/content/run_131349.csv',delimiter='\t', 
                 names=['Steering', 'TimeStamp'])
folder_path = '/content/ds_2/ds_2/images'
# Replace with the path to your folder
data = os.listdir(folder_path)
def sort_key(file_name):
    number_str = file_name.split('-')[1].split('.')[0]
    return int(number_str)

files = sorted(data, key=sort_key, reverse=False)
df['Image'] = files
last_column = df.pop('Image')
df.insert(0, 'Image', last_column)

df.head()
# Out:
#             Image  Steering  TimeStamp
# 0  movie-0000.jpg       0.0        0.0
# 1  movie-0001.jpg       0.0        0.2
# 2  movie-0002.jpg       0.0        0.4
# 3  movie-0003.jpg       0.0        0.6
# 4  movie-0004.jpg       0.0        0.8

# %%
def append_suffix(im_path):
  if isinstance(im_path, str):
    img_name, im_format = im_path.split('.')
    colab_path = '/content/ds_2/ds_2/images'
    actual_path = colab_path + "/" + img_name +'.' + im_format
    return actual_path
  else:
    return im_path


filtered_df = df[(df['Steering'] > 0.003) | (df['Steering'] < -0.003)]
indices_to_drop = filtered_df[(filtered_df['Steering'] >  0.003)  |(filtered_df['Steering'] < -0.003)].index
rows_to_drop = list(indices_to_drop)
final_df = df.drop(rows_to_drop)
filtered_df= filtered_df.dropna()
filtered_df['Image'] = filtered_df['Image'].apply(append_suffix)
filtered_df.to_csv("Delete.csv", encoding='utf-8', index=False)

print('cut off minimum steer:',final_df['Steering'].min())
print('cut off maximum steer:',final_df['Steering'].max())
print('length of dataset after removal',len(final_df))
print('dataset to be removed',len(filtered_df))
# Out:
# cut off minimum steer: -0.0029998935
# cut off maximum steer: 0.0029986035
# length of dataset after removal 25712
# dataset to be removed 5772

# %%
filtered_df.head()
# Out:
#                                        Image  Steering  TimeStamp
# 31  /content/ds_1/ds_1/images/movie-0031.jpg -0.004398        6.2
# 32  /content/ds_1/ds_1/images/movie-0032.jpg -0.005889        6.4
# 33  /content/ds_1/ds_1/images/movie-0033.jpg -0.005999        6.6
# 34  /content/ds_1/ds_1/images/movie-0034.jpg -0.006189        6.8
# 35  /content/ds_1/ds_1/images/movie-0035.jpg -0.006440        7.0

# %%
# %%capture
csv_file = r'/content/Delete.csv'
column_name = "Image"
with open(csv_file, "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        file_path = row[column_name]
        if os.path.exists(file_path):
            os.remove(file_path)
            print(f"{file_path} has been deleted.")
        else:
            print(f"{file_path} does not exist.")

# %% [markdown]
# PREPARITON : CROPPING AND RESIZING

# %%
# !mkdir ds2_PreProcessed

# %%
# %%capture
files_count=0
def prepare_files(dir_name):
    global files_count
    folder_path = dir_name
    writing_path = '/content/ds2_PreProcessed'
    print("*** Processing ", len(os.listdir(dir_name)), "files from", dir_name)
    for file in os.listdir(folder_path):
        if ".png" in file or ".jpg" in file:
            pt = os.path.join(folder_path,file)
            img = cv2.imread(pt)
            img = img[55:156,:,:]
            img = cv2.resize(img, (200, 66))

            file_name = os.path.basename(file)

            cv2.imwrite(f"{writing_path}/{file_name}", img)
            files_count+=1
            print("Processed:{} files ".format(files_count))

prepare_files('/content/ds_2/ds_2/images')

# %%
# !mkdir vgg16_PreProcessed

# %%
# %%capture
files_count=0
def prepare_files(dir_name):
    global files_count
    folder_path = dir_name
    writing_path = '/content/vgg16_PreProcessed'
    print("*** Processing ", len(os.listdir(dir_name)), "files from", dir_name)
    for file in os.listdir(folder_path):
        if ".png" in file or ".jpg" in file:
            pt = os.path.join(folder_path,file)
            img = cv2.imread(pt)
            img = img[55:156,:,:]
            img = cv2.resize(img, (224, 224))

            file_name = os.path.basename(file)

            cv2.imwrite(f"{writing_path}/{file_name}", img)
            files_count+=1
            print("Processed:{} files ".format(files_count))

prepare_files('/content/ds_2/ds_2/images')

# %%
final_df.head()
# Out:
#             Image  Steering  TimeStamp
# 0  movie-0000.jpg       0.0        0.0
# 1  movie-0001.jpg       0.0        0.2
# 2  movie-0002.jpg       0.0        0.4
# 3  movie-0003.jpg       0.0        0.6
# 4  movie-0004.jpg       0.0        0.8

# %% [markdown]
# PREPARTION: ADDING SUFFIX FOR MODEL FEED

# %%
def append_suffix(im_path):
  if isinstance(im_path, str):
    img_name, im_format = im_path.split('.')
    colab_path = '/content/ds2_PreProcessed'
    actual_path = colab_path + "/" + img_name +'.' + im_format
    return actual_path
  else:
    return im_path

final_df= final_df.dropna()
final_df['Image'] = final_df['Image'].apply(append_suffix)

# %%
global min_val
global max_val
def radians_to_degrees(radians):
    return radians * 180 / np.pi

final_df["degree"] = final_df["Steering"].apply(radians_to_degrees)
min_val = final_df["degree"].min()
max_val = final_df["degree"].max()
# normalize the values between 0 and 1
final_df["norm"] = (final_df["degree"] - min_val) / (max_val - min_val)
#Normlizae between -1 and 1
# final_df['norm'] =2 *  ((df['degree'] - min_val) / (max_val - min_val)) - 1
#Revert back
#(((df['degnorm'] + 1) * (max_val - min_val)) / 2) + min_val
print('normalized max value',final_df['norm'].max())
# Out:
# normalized max value 1.0

# %%
# final_df = pd.read_csv('final.csv')
steering = np.asarray(final_df['norm'].values)
num_bins = 15
samples_per_bin = 4500
hist, bins = np.histogram(steering, num_bins)
print(hist)
center = (bins[:-1] + bins[1:]) * 0.5
plt.bar(center, hist, width= 0.05)
plt.plot((np.min(steering), np.max(steering)), (samples_per_bin, samples_per_bin))
# Out:
# [ 332  442  463  670  875 1889 3383 7853 3382 1888  876  588  501  476
#   376]

# %%
import collections
counter = collections.Counter()

# Count the number of samples in each bin
for i in range(num_bins):

    counter[f'{bins[i]:.3f}-{bins[i+1]:.3f}'] = hist[i]

# Print the counts for each bin
for key, value in counter.items():
    print(f'{key}: {value}')
# Out:
# 0.000-0.067: 332
# 0.067-0.133: 442
# 0.133-0.200: 463
# 0.200-0.267: 670
# 0.267-0.333: 875
# 0.333-0.400: 1889
# 0.400-0.467: 3383
# 0.467-0.533: 7853
# 0.533-0.600: 3382
# 0.600-0.667: 1888
# 0.667-0.733: 876
# 0.733-0.800: 588
# 0.800-0.867: 501
# 0.867-0.933: 476
# 0.933-1.000: 376

# %% [markdown]
# Run this code for normalization and stop once it once

# %%
indices_to_drop = (final_df['norm'] >= 0.267) & (final_df['norm'] <= 0.333)
rows_to_drop = final_df[indices_to_drop].index
records_to_delete = 647
dropped_list = np.random.choice(rows_to_drop, size=records_to_delete, replace=False)
final_df.drop(dropped_list, inplace=True)

# %%
ipg_np = np.array(final_df)
#Balance the steering data
print ('total data', len(final_df))
remove_list = []
for j in range(num_bins):
  list_ = []
  for i in range(len(steering)):
    if steering[i] >= bins[j] and steering[i]<=bins[j+1]:
      #print(i)
      list_.append(i)
  list_ = shuffle(list_)
  list_ = list_[samples_per_bin:]
  remove_list.extend(list_)

print ('removed', len(remove_list))

print (np.max(remove_list))

train_data = np.delete(ipg_np, remove_list, axis=0)

print ('remaining:', len (train_data))
# Out:
# total data 23994
# removed 3353
# 23946
# remaining: 20641

# %%
#Plot balanced Steering Data
steering = []
for i in range(len(train_data)):
  steering.append(train_data[i][4])
print(steering[1])
num_bins = 15
samples_per_bin = 4500
hist, bins = np.histogram(steering, num_bins)
center = (bins[:-1] + bins[1:]) * 0.5
plt.bar(center, hist, width= 0.05)
# Out:
# 0.5001075269354974
# <BarContainer object of 15 artists>

# %%
image =[]
labels =[]
for i in range(len(train_data)):

  img,steer,ts,degree,norm = train_data[i]
  image.append(img)
  labels.append(norm)
X_train, X_valid, y_train, y_valid = train_test_split(
    image, labels, test_size=0.2, random_state=0
)

# %%
fig, axis = plt.subplots(1, 2, figsize=(12, 4))
axis[0].hist(y_train, bins=num_bins, width=0.05, color='blue')
axis[0].set_title("Training set")
axis[1].hist(y_valid, bins=num_bins, width=0.05, color='red')
axis[1].set_title("Validation set")
# Out:
# Text(0.5, 1.0, 'Validation set')

# %%
def generator(img_path,steering,batch_size):
  while True:
    for idx in range(0,len(img_path),batch_size):
      imgpath_batch = img_path[idx : idx+batch_size]
      batch_steer = steering[idx : idx+batch_size]
      lane_img = [cv2.imread(path) for path in imgpath_batch]
      yield np.asarray(lane_img),np.asarray(batch_steer)

# %% [markdown]
# # NVIDIA PILOTNET

# %%
# from keras.models import Sequential
# from keras.optimizers import Adam
# from keras.layers import Conv2D, Dropout, Flatten, Dense,Lambda

# model = Sequential()
# model.add(Lambda(lambda x: x/127.5 -1., input_shape=(66, 200, 3)))
# model.add(Conv2D(filters=24, kernel_size=(5, 5), strides=(2, 2),activation='elu'))
# model.add(Conv2D(filters=36, kernel_size=(5, 5),strides=(2, 2), activation='relu'))
# model.add(Conv2D(filters=48, kernel_size=(5, 5), strides=(2, 2),activation='relu'))
# model.add(Conv2D(filters=64, kernel_size=(3, 3) ,activation='relu'))
# model.add(Conv2D(filters=64, kernel_size=(3, 3),activation='relu'))
# model.add(Flatten())
# model.add(Dense(1164, activation='relu'))
# model.add(Dense(units=100, activation='relu'))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=10, activation='relu'))
# model.add(Dense(units=1))
# print(model.summary())

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.optimizers import Adam
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D

model = Sequential()
model.add(Lambda(lambda x: x/127.5 - 1., input_shape=(66,200, 3)))
model.add(Conv2D(filters=24, kernel_size=(5, 5), strides=(2, 2),activation='elu'))
model.add(Conv2D(filters=36, kernel_size=(5, 5),strides=(2, 2), activation='elu'))
model.add(Conv2D(filters=48, kernel_size=(5, 5), strides=(2, 2),activation='elu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3) ,activation='elu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3),activation='elu'))
model.add(Flatten())
#model.add(Dense(units=1164, activation='relu'))
model.add(Dense(units=100, activation='elu'))
model.add(Dense(units=50, activation='elu'))
model.add(Dense(units=10, activation='elu'))
model.add(Dense(units=1))
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_4 (Lambda)           (None, 66, 200, 3)        0
#
#  conv2d_20 (Conv2D)          (None, 31, 98, 24)        1824
#
#  conv2d_21 (Conv2D)          (None, 14, 47, 36)        21636
#
#  conv2d_22 (Conv2D)          (None, 5, 22, 48)         43248
#
#  conv2d_23 (Conv2D)          (None, 3, 20, 64)         27712
#
#  conv2d_24 (Conv2D)          (None, 1, 18, 64)         36928
#
#  flatten_4 (Flatten)         (None, 1152)              0
#
#  dense_16 (Dense)            (None, 100)               115300
#
#  dense_17 (Dense)            (None, 50)                5050
#
#  dense_18 (Dense)            (None, 10)                510
#
#  dense_19 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.metrics import RootMeanSquaredError
from keras.callbacks import  EarlyStopping
# es = EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss')
model.compile(loss='mse',optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
miniBatch_size = 32;
history = model.fit(generator(X_train, y_train, miniBatch_size),
                    epochs=7,
                    steps_per_epoch=int(len(X_train)/miniBatch_size),
                    validation_data=generator(X_valid, y_valid,miniBatch_size),
                    validation_steps=int(len(X_valid)/miniBatch_size),
                    shuffle=True)
                    # callbacks=[es])
model.save('ds2_modipg.h5')
# Out:
# Epoch 1/7
# 516/516 [==============================] - 11s 20ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 2/7
# 516/516 [==============================] - 8s 16ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 3/7
# 516/516 [==============================] - 9s 18ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 4/7
# 516/516 [==============================] - 11s 21ms/step - loss: 0.0041 - root_mean_squared_error: 0.0638 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 5/7
# 516/516 [==============================] - 10s 19ms/step - loss: 0.0037 - root_mean_squared_error: 0.0609 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 6/7
# 516/516 [==============================] - 8s 16ms/step - loss: 0.0034 - root_mean_squared_error: 0.0583 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 7/7
# 516/516 [==============================] - 10s 19ms/step - loss: 0.0033 - root_mean_squared_error: 0.0570 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
# %%capture
import math
import tensorflow as tf

model = tf.keras.models.load_model(r"ds2_modipg.h5")
scount = 0

def predict_image(image_path):
    global scount
    image = cv2.imread(image_path)
    # Convert the image to a numpy array
    steering = model.predict(image[None, :, :, :], batch_size=1)[0][0].astype(float)
    scount+=1
    print("files count:{}, steering:{}".format(scount,steering))
    return steering

def degrees_to_radians(degrees):
    return degrees * math.pi / 180

#Cut off for Image Scene
cuf_off = final_df[1280:1450]
cuf_off["PredDeg"] = cuf_off["Image"].apply(predict_image)
cuf_off['PredDegDeNorm'] = (cuf_off['PredDeg'] * (max_val - min_val)) + min_val
cuf_off["PredconvRadian"] = cuf_off["PredDegDeNorm"].apply(degrees_to_radians)

steering_actual = cuf_off["norm"]
timestamps = cuf_off["TimeStamp"]
steering_prediction = cuf_off['PredDeg']

# %%
cuf_off[10:25]
# Out:
#                                          Image  Steering  TimeStamp    degree  \
# 2467  /content/ds2_PreProcessed/movie-2467.jpg  0.002188      493.4  0.125353
# 2468  /content/ds2_PreProcessed/movie-2468.jpg  0.002110      493.6  0.120866
# 2469  /content/ds2_PreProcessed/movie-2469.jpg  0.002033      493.8  0.116509
# 2470  /content/ds2_PreProcessed/movie-2470.jpg  0.001962      494.0  0.112433
# 2471  /content/ds2_PreProcessed/movie-2471.jpg  0.001892      494.2  0.108379
# 2472  /content/ds2_PreProcessed/movie-2472.jpg  0.001832      494.4  0.104982
# 2473  /content/ds2_PreProcessed/movie-2473.jpg  0.001776      494.6  0.101764
# 2474  /content/ds2_PreProcessed/movie-2474.jpg  0.001722      494.8  0.098682
# 2475  /content/ds2_PreProcessed/movie-2475.jpg  0.001673      495.0  0.095871
# 2476  /content/ds2_PreProcessed/movie-2476.jpg  0.001625      495.2  0.093107
# 2477  /content/ds2_PreProcessed/movie-2477.jpg  0.001582      495.4  0.090662
# 2478  /content/ds2_PreProcessed/movie-2478.jpg  0.001542      495.6  0.088378
# 2479  /content/ds2_PreProcessed/movie-2479.jpg  0.001493      495.8  0.085525
# 2480  /content/ds2_PreProcessed/movie-2480.jpg  0.001444      496.0  0.082737
# 2481  /content/ds2_PreProcessed/movie-2481.jpg  0.001387      496.2  0.079482
#
#           norm   PredDeg  PredDegDeNorm  PredconvRadian
# 2467  0.864837  0.728877       0.078626        0.001372
# 2468  0.851780  0.717266       0.074635        0.001303
# 2469  0.839103  0.721248       0.076003        0.001327
# 2470  0.827242  0.756371       0.088075        0.001537
# 2471  0.815448  0.797405       0.102178        0.001783
# 2472  0.805563  0.819518       0.109778        0.001916
# 2473  0.796203  0.848078       0.119593        0.002087
# 2474  0.787234  0.832055       0.114087        0.001991
# 2475  0.779054  0.737658       0.081643        0.001425
# 2476  0.771013  0.742663       0.083364        0.001455
# 2477  0.763900  0.730588       0.079214        0.001383
# 2478  0.757254  0.788621       0.099159        0.001731
# 2479  0.748953  0.730872       0.079311        0.001384
# 2480  0.740839  0.824024       0.111326        0.001943
# 2481  0.731370  0.809073       0.106188        0.001853

# %%
def show_actual():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_actual, color='darkblue', label='Actual')
    # ax.plot(timestamps, steering_prediction, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp(seconds)')
    ax.set_ylabel('Steering Angle (radians)')
    ax.set_title('Actual Steering Angle')
    plt.show()

def show_prediction():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_prediction, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp(seconds)')
    ax.set_ylabel('Steering Angle(radians)')
    ax.set_title('Predicted Steering Angle')

    plt.show()

# %%
show_actual()

# %%
show_prediction()

# %% [markdown]
# # TRANSFER LEARNING

# %%
from keras.models import Model
from keras.applications.vgg16 import  VGG16
from keras.layers import Dense, GlobalAveragePooling2D,BatchNormalization,Lambda
from keras.optimizers import Adam

def normalize_input(x):
    return x/255


mod_shape = (66, 200, 3)
base_model = VGG16(weights='imagenet', include_top=False,input_shape=(224,224,3))
# input_layer = Lambda(normalize_input, input_shape=mod_shape)(base_model.input),

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1164,activation='relu')(x)
x = Dense(100,activation='relu')(x)
# x = Dropout(0.5)(x)
x = Dense(50,activation='relu')(x)
# x = Dropout(0.5)(x)
x = Dense(10,activation='relu')(x)
predictions = Dense(1)(x)
model =  Model(inputs=base_model.input,outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1164)              597132
#
#  dense_1 (Dense)             (None, 100)               116500
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 10)                510
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 15,433,891
# Trainable params: 15,433,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from keras.metrics import RootMeanSquaredError
from keras.callbacks import  EarlyStopping
# es = EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss')
model.compile(loss='mse',optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
miniBatch_size = 32;

history = model.fit(generator(X_train, y_train, miniBatch_size),
                    epochs=10,
                    steps_per_epoch=int(len(X_train)/miniBatch_size),
                    validation_data=generator(X_valid, y_valid,miniBatch_size),
                    validation_steps=int(len(X_valid)/miniBatch_size),
                    shuffle=True)
model.save('ds2_vgg16ipg.h5')
# Out:
# Epoch 1/10
# 542/542 [==============================] - 91s 145ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 2/10
# 542/542 [==============================] - 85s 151ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 3/10
# 542/542 [==============================] - 87s 160ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 4/10
# 542/542 [==============================] - 83s 154ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 5/10
# 542/542 [==============================] - 84s 156ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0766
# Epoch 6/10
# 542/542 [==============================] - 88s 163ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 7/10
# 542/542 [==============================] - 88s 163ms/step - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 8/10
# 542/542 [==============================] - 88s 163ms/step - loss: 0.0035 - root_mean_squared_error: 0.0589 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 9/10
# 542/542 [==============================] - 84s 155ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 10/10
# 542/542 [==============================] - 85s 157ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
scount=0
def predict_image(image_path):
    global scount
    image = cv2.imread(image_path)
    # image = image /255
    # Convert the image to a numpy array
    steering = model.predict(image[None, :, :, :], batch_size=1)[0][0].astype(float)
    scount+=1
    # print("files count:{}, steering:{}".format(scount,steering))
    return steering

def degrees_to_radians(degrees):
    return degrees * math.pi / 180

cut_off = final_df[1250:1300]
cut_off["PredDeg"] = cut_off["Image"].apply(predict_image)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# <ipython-input-33-da1397ae1eb3>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_off["PredDeg"] = cut_off["Image"].apply(predict_image)

# %%
cut_off.head(50)
# Out:
#                                            Image  Steering  TimeStamp  \
# 2268  /content/vgg16_PreProcessed/movie-2268.jpg -0.000182      453.6
# 2269  /content/vgg16_PreProcessed/movie-2269.jpg -0.000291      453.8
# 2270  /content/vgg16_PreProcessed/movie-2270.jpg -0.000385      454.0
# 2271  /content/vgg16_PreProcessed/movie-2271.jpg -0.000458      454.2
# 2272  /content/vgg16_PreProcessed/movie-2272.jpg -0.000521      454.4
# 2273  /content/vgg16_PreProcessed/movie-2273.jpg -0.000565      454.6
# 2274  /content/vgg16_PreProcessed/movie-2274.jpg -0.000590      454.8
# 2275  /content/vgg16_PreProcessed/movie-2275.jpg -0.000587      455.0
# 2276  /content/vgg16_PreProcessed/movie-2276.jpg -0.000540      455.2
# 2277  /content/vgg16_PreProcessed/movie-2277.jpg -0.000457      455.4
# 2278  /content/vgg16_PreProcessed/movie-2278.jpg -0.000315      455.6
# 2279  /content/vgg16_PreProcessed/movie-2279.jpg -0.000120      455.8
# 2280  /content/vgg16_PreProcessed/movie-2280.jpg  0.000128      456.0
# 2281  /content/vgg16_PreProcessed/movie-2281.jpg  0.000431      456.2
# 2282  /content/vgg16_PreProcessed/movie-2282.jpg  0.000771      456.4
# 2283  /content/vgg16_PreProcessed/movie-2283.jpg  0.001170      456.6
# 2284  /content/vgg16_PreProcessed/movie-2284.jpg  0.001592      456.8
# 2285  /content/vgg16_PreProcessed/movie-2285.jpg  0.002061      457.0
# 2286  /content/vgg16_PreProcessed/movie-2286.jpg  0.002558      457.2
# 2318  /content/vgg16_PreProcessed/movie-2318.jpg  0.002558      463.6
# 2319  /content/vgg16_PreProcessed/movie-2319.jpg  0.001648      463.8
# 2320  /content/vgg16_PreProcessed/movie-2320.jpg  0.000738      464.0
# 2321  /content/vgg16_PreProcessed/movie-2321.jpg -0.000164      464.2
# 2322  /content/vgg16_PreProcessed/movie-2322.jpg -0.001046      464.4
# 2323  /content/vgg16_PreProcessed/movie-2323.jpg -0.001883      464.6
# 2324  /content/vgg16_PreProcessed/movie-2324.jpg -0.002670      464.8
# 2365  /content/vgg16_PreProcessed/movie-2365.jpg -0.002647      473.0
# 2366  /content/vgg16_PreProcessed/movie-2366.jpg -0.002235      473.2
# 2367  /content/vgg16_PreProcessed/movie-2367.jpg -0.001813      473.4
# 2368  /content/vgg16_PreProcessed/movie-2368.jpg -0.001378      473.6
# 2369  /content/vgg16_PreProcessed/movie-2369.jpg -0.000926      473.8
# 2370  /content/vgg16_PreProcessed/movie-2370.jpg -0.000450      474.0
# 2371  /content/vgg16_PreProcessed/movie-2371.jpg -0.000007      474.2
# 2372  /content/vgg16_PreProcessed/movie-2372.jpg  0.000427      474.4
# 2373  /content/vgg16_PreProcessed/movie-2373.jpg  0.000872      474.6
# 2374  /content/vgg16_PreProcessed/movie-2374.jpg  0.001310      474.8
# 2375  /content/vgg16_PreProcessed/movie-2375.jpg  0.001723      475.0
# 2376  /content/vgg16_PreProcessed/movie-2376.jpg  0.002133      475.2
# 2377  /content/vgg16_PreProcessed/movie-2377.jpg  0.002508      475.4
# 2378  /content/vgg16_PreProcessed/movie-2378.jpg  0.002823      475.6
# 2398  /content/vgg16_PreProcessed/movie-2398.jpg  0.002924      479.6
# 2399  /content/vgg16_PreProcessed/movie-2399.jpg  0.002724      479.8
# 2400  /content/vgg16_PreProcessed/movie-2400.jpg  0.002497      480.0
# 2401  /content/vgg16_PreProcessed/movie-2401.jpg  0.002255      480.2
# 2402  /content/vgg16_PreProcessed/movie-2402.jpg  0.001999      480.4
# 2403  /content/vgg16_PreProcessed/movie-2403.jpg  0.001723      480.6
# 2404  /content/vgg16_PreProcessed/movie-2404.jpg  0.001420      480.8
# 2405  /content/vgg16_PreProcessed/movie-2405.jpg  0.001091      481.0
# 2406  /content/vgg16_PreProcessed/movie-2406.jpg  0.000735      481.2
# 2407  /content/vgg16_PreProcessed/movie-2407.jpg  0.000383      481.4
#
#         degree      norm   PredDeg
# 2268 -0.010414  0.469806  0.480102
# 2269 -0.016658  0.451638  0.479986
# 2270 -0.022058  0.435929  0.395354
# 2271 -0.026267  0.423681  0.456362
# 2272 -0.029868  0.413202  0.401140
# 2273 -0.032347  0.405991  0.465701
# 2274 -0.033789  0.401795  0.414213
# 2275 -0.033626  0.402269  0.367493
# 2276 -0.030938  0.410090  0.438554
# 2277 -0.026182  0.423927  0.460243
# 2278 -0.018076  0.447512  0.446401
# 2279 -0.006863  0.480140  0.503005
# 2280  0.007348  0.521487  0.554687
# 2281  0.024685  0.571931  0.499273
# 2282  0.044153  0.628575  0.520964
# 2283  0.067026  0.695127  0.628336
# 2284  0.091234  0.765563  0.654873
# 2285  0.118061  0.843620  0.686286
# 2286  0.146586  0.926615  0.681381
# 2318  0.146591  0.926629  0.481643
# 2319  0.094406  0.774793  0.466939
# 2320  0.042265  0.623082  0.475540
# 2321 -0.009370  0.472844  0.476268
# 2322 -0.059914  0.325782  0.333738
# 2323 -0.107869  0.186250  0.320887
# 2324 -0.153000  0.054936  0.173551
# 2365 -0.151644  0.058882  0.293182
# 2366 -0.128034  0.127579  0.227316
# 2367 -0.103856  0.197927  0.333552
# 2368 -0.078951  0.270390  0.302855
# 2369 -0.053055  0.345738  0.335777
# 2370 -0.025772  0.425122  0.435692
# 2371 -0.000374  0.499020  0.460155
# 2372  0.024489  0.571362  0.667399
# 2373  0.049970  0.645502  0.532698
# 2374  0.075042  0.718451  0.754761
# 2375  0.098735  0.787388  0.665115
# 2376  0.122234  0.855760  0.864493
# 2377  0.143698  0.918213  0.762073
# 2378  0.161729  0.970676  0.872959
# 2398  0.167550  0.987614  0.833366
# 2399  0.156053  0.954161  0.797216
# 2400  0.143092  0.916450  0.799403
# 2401  0.129218  0.876081  0.756442
# 2402  0.114512  0.833291  0.716164
# 2403  0.098737  0.787395  0.640728
# 2404  0.081377  0.736883  0.562712
# 2405  0.062512  0.681994  0.651214
# 2406  0.042115  0.622645  0.515568
# 2407  0.021970  0.564032  0.575476

# %% [markdown]
# # DATASET 3 PREPROCESSING

# %%
import shutil

# Specify the directory path to be removed
directory_path = "/content/ds_3"

# Remove the directory and all its contents
shutil.rmtree(directory_path)

# %%
# %%capture
# !kaggle datasets download -d shyamsundaravce/ipgcarmker-ds3

# !unzip  /content/ipgcarmker-ds3.zip

# %%
len(os.listdir('/content/ds_3/ds_3/images'))
# Out:
# 30432

# %%
df = pd.read_csv(r'/content/run_13052023.csv')
df = df.drop(df.index[-1])#There is one excess record
folder_path = r'/content/ds_3/ds_3/images'
# Replace with the path to your folder
data = os.listdir(folder_path)
def sort_key(file_name):
    number_str = file_name.split('-')[1].split('.')[0]
    return int(number_str)

files = sorted(data, key=sort_key, reverse=False)
df['Image'] = files
last_column = df.pop('Image')
df.insert(0, 'Image', last_column)


def append_suffix(im_path):
  if isinstance(im_path, str):
    img_name, im_format = im_path.split('.')
    colab_path = '/content/ds_3/ds_3/images'
    actual_path = colab_path + "/" + img_name +'.' + im_format
    return actual_path
  else:
    return im_path


filtered_df = df[(df['Steering'] > 0.003) | (df['Steering'] < -0.003)]
indices_to_drop = filtered_df[(filtered_df['Steering'] >  0.003)  |(filtered_df['Steering'] < -0.003)].index
rows_to_drop = list(indices_to_drop)
final_df = df.drop(rows_to_drop)
filtered_df= filtered_df.dropna()
filtered_df['Image'] = filtered_df['Image'].apply(append_suffix)
filtered_df.to_csv("Delete.csv", encoding='utf-8', index=False)

print('cut off minimum steer:',final_df['Steering'].min())
print('cut off maximum steer:',final_df['Steering'].max())
print('length of dataset after removal',len(final_df))
print('dataset to be removed',len(filtered_df))
# Out:
# cut off minimum steer: -0.002998968
# cut off maximum steer: 0.002999177
# length of dataset after removal 27127
# dataset to be removed 3305

# %%
#Please run at once to delete the files using delete.csv
csv_file = "/content/Delete.csv"
column_name = "Image"
with open(csv_file, "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        file_path = row[column_name]
        if os.path.exists(file_path):
            os.remove(file_path)
            print(f"{file_path} has been deleted.")
        else:
            print(f"{file_path} does not exist.")
# Out:
# /content/ds_3/ds_3/images/movie-0015.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0016.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0017.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0018.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0019.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0020.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0021.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0022.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0023.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0024.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0025.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0026.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0027.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0028.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0029.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0034.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0035.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0036.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0037.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0038.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0039.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0040.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0041.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0471.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0472.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0473.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0474.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0475.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0476.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0477.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0478.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0479.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0480.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0481.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0482.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0483.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0484.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0485.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0486.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0487.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0488.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0489.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0490.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0491.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0492.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0493.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0494.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0495.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0496.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0497.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0498.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0499.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0500.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0501.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0502.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0503.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0504.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0505.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0506.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0507.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0508.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0509.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0510.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0511.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0512.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0513.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0514.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0515.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0516.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0517.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0520.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0521.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0522.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0523.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0524.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0525.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0526.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0527.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0528.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0529.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0530.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0531.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0532.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0533.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0534.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0535.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0536.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0537.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0538.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0539.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0540.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0541.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0542.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0543.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0544.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0545.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0546.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0547.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0548.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0549.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0550.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0551.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0552.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0553.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0554.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0555.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0556.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0557.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0558.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0559.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0560.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0561.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0562.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0563.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0564.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0565.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0566.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0567.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0568.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0569.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0570.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0571.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0572.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-0574.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7307.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7308.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7309.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7310.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7311.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7312.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7313.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7314.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7315.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7316.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7317.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7318.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7319.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7320.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7321.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7322.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7323.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7324.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7325.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7326.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7327.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7328.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7329.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7330.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7331.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7332.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7333.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7334.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7335.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7336.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7337.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7338.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7339.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7340.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7341.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7342.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7365.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7366.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7367.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7368.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7369.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7370.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7371.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7372.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7373.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7374.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7375.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7376.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7377.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7378.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7379.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7434.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7435.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7436.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7437.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7438.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7439.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7440.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7441.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7442.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7443.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7444.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7445.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7446.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7447.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7448.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7449.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7450.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7451.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7452.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7453.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7454.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7455.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7456.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7457.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7458.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7459.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7460.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7461.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7462.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7463.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7464.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7465.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7466.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7467.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7468.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7469.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7470.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7471.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7472.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7473.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7474.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7475.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7476.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7477.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7478.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7479.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7480.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7481.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7482.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7483.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7484.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7485.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7486.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7487.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7488.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7489.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7490.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7491.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7492.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7493.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7494.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7495.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7496.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7497.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7498.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7499.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7500.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7501.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7502.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7503.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7504.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7505.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7506.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7507.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7508.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7509.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7510.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7511.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7512.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7513.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7514.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7515.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7516.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7517.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7518.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7519.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7520.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7521.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7522.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7523.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7524.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7525.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7526.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7527.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7528.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7529.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7530.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7531.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7532.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7533.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7534.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7535.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7536.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7537.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7538.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7539.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7540.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7541.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7542.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7543.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7544.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7545.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7546.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7547.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7548.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7549.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7550.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7551.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7552.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7553.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7554.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7555.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7556.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7557.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7558.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7559.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7560.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7561.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7562.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7563.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7564.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7565.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7566.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7567.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7568.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7569.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7570.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7571.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7572.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7573.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7574.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7575.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7576.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7577.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7578.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7579.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7580.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7581.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7582.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7583.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7584.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7585.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7586.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7587.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7588.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7589.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7590.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7591.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7592.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-7593.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11012.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11013.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11014.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11015.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11016.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11017.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11018.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11019.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11020.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11021.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11022.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11023.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11024.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11025.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11026.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11027.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11028.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11029.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11030.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11031.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11032.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11033.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11034.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11035.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11036.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11037.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11038.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11039.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11040.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11041.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11042.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11043.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11044.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11045.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11046.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11047.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11048.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11049.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11050.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11051.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11052.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11053.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11054.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11055.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11056.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11057.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11058.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11059.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11060.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11061.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11062.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11063.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11064.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11065.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11066.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11067.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11068.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11069.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11070.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11071.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11072.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11073.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11074.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11075.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11076.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11077.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11078.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11079.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11080.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11081.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11082.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11083.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11084.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11085.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11086.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11087.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11088.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11089.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11090.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11091.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11092.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11093.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11094.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11095.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11096.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11097.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11098.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11099.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11100.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11101.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11102.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11103.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11104.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11105.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11106.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-11107.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13501.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13502.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13503.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13504.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13505.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13506.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13507.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13508.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13509.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13510.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13511.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13512.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13513.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13514.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13515.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13516.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13517.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13518.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13519.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13520.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13521.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13522.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13523.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13524.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13525.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13526.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13527.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13528.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13529.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13530.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13531.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13532.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13533.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13534.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13535.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13540.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13541.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13542.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13543.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13544.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13545.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13546.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13547.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13548.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13549.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13550.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13551.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13552.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13553.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13554.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13555.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13556.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13557.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13558.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13559.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13560.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13561.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13562.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13563.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13564.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13565.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13566.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13567.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13568.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13569.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13570.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13571.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13572.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13573.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13574.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13575.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13576.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13577.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13578.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13579.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13580.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13581.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13582.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13583.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13584.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13585.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13586.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13587.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13766.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13767.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13768.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13769.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13770.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13771.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13772.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13773.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13774.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13775.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13776.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13777.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13778.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13779.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13781.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13782.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13783.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13784.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13785.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13786.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13787.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13788.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13789.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13790.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13791.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13792.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13793.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13794.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13795.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13796.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13797.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13798.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13799.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13801.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13802.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13803.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13804.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13805.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13806.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13807.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13808.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13809.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13810.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13811.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13812.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13973.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13974.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13975.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13976.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13977.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13978.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13979.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13980.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13981.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13982.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13983.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13984.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13985.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13986.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13987.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13988.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13989.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13990.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13991.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13992.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13993.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13994.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13995.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13996.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13997.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13998.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-13999.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14000.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14003.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14004.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14005.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14006.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14007.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14008.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14009.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14010.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14011.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14012.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14013.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14014.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14015.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14016.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14017.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14018.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14019.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14020.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14021.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14022.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14023.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14024.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14025.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14026.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14027.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14028.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14074.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14075.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14076.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14077.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14078.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14079.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14080.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14081.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14082.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14083.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14084.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14085.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14086.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14087.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14088.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14089.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14090.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14091.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14092.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14093.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14094.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14095.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14096.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14097.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14098.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14099.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14100.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14101.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14102.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14103.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14104.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14105.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14106.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14107.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14108.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14109.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14110.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14111.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14112.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14113.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14114.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14160.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14161.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14162.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14163.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14164.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14165.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14166.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14167.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14168.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14169.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14170.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14171.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14172.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14173.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14174.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14175.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14176.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14177.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14211.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14212.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14213.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14214.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14215.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14216.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14217.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14218.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14219.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14220.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14221.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14222.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14223.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14224.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14225.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14226.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14227.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14228.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14229.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14230.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14231.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14232.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14233.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14234.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14235.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14236.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14237.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14243.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14244.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14245.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14246.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14247.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14248.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14249.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14250.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14251.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14252.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14253.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14254.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14255.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14256.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14257.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14258.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14259.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14260.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14261.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14262.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14263.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14264.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-14265.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15687.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15688.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15689.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15690.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15691.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15692.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15693.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15694.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15773.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15774.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15775.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15776.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15777.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15778.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15779.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15780.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15781.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15782.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15783.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15784.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15785.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15786.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15787.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15788.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15789.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15790.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15791.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15792.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15793.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15794.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15795.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15796.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15797.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15798.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15799.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15800.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15801.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15802.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-15803.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16169.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16170.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16171.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16172.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16173.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16174.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16175.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16176.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16177.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-16178.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17705.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17706.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17707.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17708.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17709.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17710.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17711.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17712.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17713.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17714.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17715.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17716.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17717.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17718.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17719.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17720.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17721.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17722.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17723.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17724.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17725.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17726.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17727.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17728.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17729.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17730.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17731.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17732.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17733.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17734.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17735.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17736.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17737.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-17738.jpg has been deleted.
# ...
# /content/ds_3/ds_3/images/movie-29782.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29783.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29784.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29785.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29786.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29787.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29788.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29789.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29790.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29791.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29792.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29793.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29931.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29932.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29933.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-29934.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30054.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30055.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30056.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30057.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30058.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30059.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30060.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30061.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30062.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30063.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30064.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30065.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30066.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30067.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30068.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30069.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30070.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30071.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30072.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30073.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30074.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30075.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30076.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30077.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30078.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30079.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30080.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30081.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30082.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30083.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30084.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30085.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30086.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30087.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30088.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30089.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30090.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30091.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30092.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30093.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30094.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30095.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30096.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30097.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30098.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30099.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30100.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30101.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30102.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30103.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30104.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30105.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30106.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30107.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30108.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30109.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30110.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30111.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30112.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30113.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30114.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30115.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30116.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30117.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30118.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30119.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30120.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30121.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30122.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30123.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30124.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30125.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30126.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30127.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30128.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30129.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30141.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30142.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30143.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30144.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30145.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30146.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30147.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30148.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30149.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30150.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30151.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30152.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30153.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30154.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30155.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30156.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30157.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30158.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30159.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30160.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30161.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30162.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30163.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30164.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30165.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30166.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30167.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30168.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30169.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30170.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30171.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30172.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30173.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30174.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30175.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30176.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30177.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30178.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30179.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30180.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30181.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30182.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30183.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30184.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30185.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30186.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30187.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30201.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30202.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30203.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30204.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30205.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30206.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30207.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30208.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30209.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30210.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30211.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30212.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30213.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30214.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30215.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30216.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30249.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30250.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30251.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30252.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30253.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30254.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30255.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30256.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30257.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30258.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30259.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30260.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30261.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30262.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30263.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30264.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30265.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30266.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30267.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30268.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30269.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30270.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30271.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30272.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30273.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30274.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30275.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30276.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30277.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30278.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30279.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30280.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30281.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30282.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30283.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30284.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30285.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30286.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30287.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30288.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30289.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30290.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30291.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30335.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30336.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30337.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30338.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30339.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30340.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30341.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30342.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30343.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30344.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30345.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30346.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30347.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30348.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30349.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30350.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30351.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30352.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30353.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30354.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30355.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30356.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30357.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30358.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30359.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30360.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30361.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30362.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30363.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30364.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30365.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30366.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30396.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30397.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30398.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30399.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30400.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30401.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30402.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30403.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30404.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30405.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30406.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30407.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30408.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30409.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30410.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30411.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30412.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30413.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30414.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30415.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30416.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30417.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30418.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30419.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30420.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30421.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30422.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30423.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30424.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30425.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30426.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30427.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30428.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30429.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30430.jpg has been deleted.
# /content/ds_3/ds_3/images/movie-30431.jpg has been deleted.

# %%
# !mkdir ds3_PreProcessed

# %%
# %%capture
files_count=0
def prepare_files(dir_name):
    global files_count
    folder_path = dir_name
    writing_path = "/content/ds3_PreProcessed"
    print("*** Processing ", len(os.listdir(dir_name)), "files from", dir_name)
    for file in os.listdir(folder_path):
        if ".png" in file or ".jpg" in file:
            pt = os.path.join(folder_path,file)
            img = cv2.imread(pt)
            img = img[55:156,:,:]
            img = cv2.resize(img, (200, 66))

            file_name = os.path.basename(file)

            cv2.imwrite(f"{writing_path}/{file_name}", img)
            files_count+=1
            # print("Processed:{} files ".format(files_count))

prepare_files("/content/ds_3/ds_3/images")
print("Processed:{} files ".format(files_count))

# %%
def append_suffix(im_path):
  if isinstance(im_path, str):
    img_name, im_format = im_path.split('.')
    colab_path = '/content/ds3_PreProcessed'
    actual_path = colab_path + "/" + img_name +'.' + im_format
    return actual_path
  else:
    return im_path

final_df= final_df.dropna()
final_df['Image'] = final_df['Image'].apply(append_suffix)

# %%
final_df.head()
# Out:
#                                       Image  Steering  TimeStamp
# 0  /content/ds3_PreProcessed/movie-0000.jpg       0.0        0.0
# 1  /content/ds3_PreProcessed/movie-0001.jpg       0.0        0.0
# 2  /content/ds3_PreProcessed/movie-0002.jpg       0.0        0.2
# 3  /content/ds3_PreProcessed/movie-0003.jpg       0.0        0.4
# 4  /content/ds3_PreProcessed/movie-0004.jpg       0.0        0.6

# %% [markdown]
# # DATASET 3 PREDICTIONS

# %%
global d3min_val
global d3max_val
def radians_to_degrees(radians):
    return radians * 180 / np.pi

final_df["degree"] = final_df["Steering"].apply(radians_to_degrees)
final_df = final_df[7060:7300]
d3min_val = final_df["degree"].min()
d3max_val = final_df["degree"].max()
# normalize the values between 0 and 1
final_df["norm"] = (final_df["degree"] - d3min_val) / (d3max_val - d3min_val)
#Normlizae between -1 and 1
# final_df['norm'] =2 *  ((df['degree'] - min_val) / (max_val - min_val)) - 1
#Revert back
#(((df['degnorm'] + 1) * (max_val - min_val)) / 2) + min_val
print('normalized max value',final_df['norm'].max())
# Out:
# normalized max value 1.0
# <ipython-input-64-dce85a4e1abc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["norm"] = (final_df["degree"] - d3min_val) / (d3max_val - d3min_val)

# %%
final_df.head()
# Out:
#                                          Image  Steering  TimeStamp    degree  \
# 7184  /content/ds3_PreProcessed/movie-7184.jpg  0.000690     1436.6  0.039545
# 7185  /content/ds3_PreProcessed/movie-7185.jpg  0.000703     1436.8  0.040262
# 7186  /content/ds3_PreProcessed/movie-7186.jpg  0.000715     1437.0  0.040946
# 7187  /content/ds3_PreProcessed/movie-7187.jpg  0.000726     1437.2  0.041585
# 7188  /content/ds3_PreProcessed/movie-7188.jpg  0.000737     1437.4  0.042222
#
#           norm
# 7184  0.617297
# 7185  0.619391
# 7186  0.621390
# 7187  0.623257
# 7188  0.625118

# %%
# %%capture
import tensorflow as tf
import math
model = tf.keras.models.load_model("/content/ds2_modipg.h5")
scount = 0
def predict_image(image_path):
    global scount
    image = cv2.imread(image_path)
    # image = image /255
    # Convert the image to a numpy array
    steering = model.predict(image[None, :, :, :], batch_size=1)[0][0].astype(float)
    scount+=1
    # print("files count:{}, steering:{}".format(scount,steering))
    return steering

def degrees_to_radians(degrees):
    return degrees * math.pi / 180

cuf_off = final_df# First 288
cuf_off["PredDeg"] = cuf_off["Image"].apply(predict_image)
cuf_off['PredDeNorm'] = (cuf_off['PredDeg'] * (d3max_val - d3min_val)) + d3min_val
cuf_off["PredRadian"] = cuf_off["PredDeNorm"].apply(degrees_to_radians)

# %%
cuf_off.head(10)
# Out:
#                                          Image  Steering  TimeStamp    degree  \
# 7184  /content/ds3_PreProcessed/movie-7184.jpg  0.000690     1436.6  0.039545
# 7185  /content/ds3_PreProcessed/movie-7185.jpg  0.000703     1436.8  0.040262
# 7186  /content/ds3_PreProcessed/movie-7186.jpg  0.000715     1437.0  0.040946
# 7187  /content/ds3_PreProcessed/movie-7187.jpg  0.000726     1437.2  0.041585
# 7188  /content/ds3_PreProcessed/movie-7188.jpg  0.000737     1437.4  0.042222
# 7189  /content/ds3_PreProcessed/movie-7189.jpg  0.000747     1437.6  0.042808
# 7190  /content/ds3_PreProcessed/movie-7190.jpg  0.000755     1437.8  0.043280
# 7191  /content/ds3_PreProcessed/movie-7191.jpg  0.000762     1438.0  0.043653
# 7192  /content/ds3_PreProcessed/movie-7192.jpg  0.000766     1438.2  0.043914
# 7193  /content/ds3_PreProcessed/movie-7193.jpg  0.000771     1438.4  0.044173
#
#           norm   PredDeg  PredDeNorm  PredRadian
# 7184  0.617297  0.656828    0.053075    0.000926
# 7185  0.619391  0.666113    0.056254    0.000982
# 7186  0.621390  0.605956    0.035663    0.000622
# 7187  0.623257  0.637282    0.046385    0.000810
# 7188  0.625118  0.655518    0.052627    0.000919
# 7189  0.626831  0.569710    0.023258    0.000406
# 7190  0.628209  0.570569    0.023551    0.000411
# 7191  0.629299  0.609307    0.036810    0.000642
# 7192  0.630061  0.572732    0.024292    0.000424
# 7193  0.630820  0.589897    0.030167    0.000527

# %%
steering_actual = cuf_off["norm"]
timestamps = cuf_off["TimeStamp"]
steering_prediction = cuf_off['PredDeg']
def show_actual():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_actual, color='darkblue', label='Actual')
    # ax.plot(timestamps, steering_prediction, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp(seconds)')
    ax.set_ylabel('Steering Angle(Radians)')
    ax.set_title('Actual Steering Angle ')
    plt.show()

def show_prediction():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_prediction, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp(seconds)')
    ax.set_ylabel('Steering Angle(Radians)')
    ax.set_title('Predicted Steering Angle')

    plt.show()

# %%
show_actual()

# %%
show_prediction()

# %%
import tensorflow as tf

model = tf.keras.models.load_model(r"/content/ds2_vgg16ipg.h5")
scount = 0

def predict_image(image_path):
    global scount
    image = cv2.imread(image_path)
    # Convert the image to a numpy array
    image = image /255
    steering = model.predict(image[None, :, :, :], batch_size=1)[0][0].astype(float)
    scount+=1
    print("files count:{}, steering:{}".format(scount,steering))
    return steering
vgg16_df = df[0:500]
vgg16_df["VGG16_PredDeg"] = vgg16_df["Image"].apply(predict_image)
vgg16_df.to_csv('VGG16-DS2PRED3.csv',index=False)
# Out:
# 1/1 [==============================] - 0s 231ms/step
# files count:1, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:2, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:3, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:4, steering:0.09607943147420883
# 1/1 [==============================] - 0s 29ms/step
# files count:5, steering:0.09607943147420883
# 1/1 [==============================] - 0s 28ms/step
# files count:6, steering:0.09607943147420883
# 1/1 [==============================] - 0s 29ms/step
# files count:7, steering:0.09607943147420883
# 1/1 [==============================] - 0s 36ms/step
# files count:8, steering:0.09607943147420883
# 1/1 [==============================] - 0s 28ms/step
# files count:9, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:10, steering:0.09607943147420883
# 1/1 [==============================] - 0s 26ms/step
# files count:11, steering:0.09607943147420883
# 1/1 [==============================] - 0s 37ms/step
# files count:12, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:13, steering:0.09607943147420883
# 1/1 [==============================] - 0s 25ms/step
# files count:14, steering:0.09607943147420883
# 1/1 [==============================] - 0s 26ms/step
# files count:15, steering:0.09607943147420883
# 1/1 [==============================] - 0s 29ms/step
# files count:16, steering:0.09607943147420883
# 1/1 [==============================] - 0s 20ms/step
# files count:17, steering:0.09607943147420883
# 1/1 [==============================] - 0s 17ms/step
# files count:18, steering:0.09607943147420883
# 1/1 [==============================] - 0s 16ms/step
# files count:19, steering:0.09607943147420883
# 1/1 [==============================] - 0s 20ms/step
# files count:20, steering:0.09607943147420883
# 1/1 [==============================] - 0s 19ms/step
# files count:21, steering:0.1550164818763733
# 1/1 [==============================] - 0s 17ms/step
# files count:22, steering:0.19634667038917542
# 1/1 [==============================] - 0s 18ms/step
# files count:23, steering:0.22159850597381592
# 1/1 [==============================] - 0s 22ms/step
# files count:24, steering:0.3348758816719055
# 1/1 [==============================] - 0s 29ms/step
# files count:25, steering:0.4831142723560333
# 1/1 [==============================] - 0s 20ms/step
# files count:26, steering:0.5262094736099243
# 1/1 [==============================] - 0s 20ms/step
# files count:27, steering:0.5211676359176636
# 1/1 [==============================] - 0s 23ms/step
# files count:28, steering:0.5680040717124939
# 1/1 [==============================] - 0s 20ms/step
# files count:29, steering:0.6908234357833862
# 1/1 [==============================] - 0s 19ms/step
# files count:30, steering:0.6409753561019897
# 1/1 [==============================] - 0s 17ms/step
# files count:31, steering:0.6719959378242493
# 1/1 [==============================] - 0s 20ms/step
# files count:32, steering:0.5673754215240479
# 1/1 [==============================] - 0s 27ms/step
# files count:33, steering:0.7008219361305237
# 1/1 [==============================] - 0s 17ms/step
# files count:34, steering:0.5836319923400879
# 1/1 [==============================] - 0s 19ms/step
# files count:35, steering:0.5786184072494507
# 1/1 [==============================] - 0s 17ms/step
# files count:36, steering:0.6695554256439209
# 1/1 [==============================] - 0s 18ms/step
# files count:37, steering:0.6019051671028137
# 1/1 [==============================] - 0s 20ms/step
# files count:38, steering:0.5599154829978943
# 1/1 [==============================] - 0s 23ms/step
# files count:39, steering:0.5561298131942749
# 1/1 [==============================] - 0s 20ms/step
# files count:40, steering:0.5694778561592102
# 1/1 [==============================] - 0s 21ms/step
# files count:41, steering:0.5205890536308289
# 1/1 [==============================] - 0s 21ms/step
# files count:42, steering:0.565325915813446
# 1/1 [==============================] - 0s 18ms/step
# files count:43, steering:0.5930801630020142
# 1/1 [==============================] - 0s 21ms/step
# files count:44, steering:0.5135796666145325
# 1/1 [==============================] - 0s 19ms/step
# files count:45, steering:0.571832537651062
# 1/1 [==============================] - 0s 18ms/step
# files count:46, steering:0.521614134311676
# 1/1 [==============================] - 0s 19ms/step
# files count:47, steering:0.4891572892665863
# 1/1 [==============================] - 0s 16ms/step
# files count:48, steering:0.5054773688316345
# 1/1 [==============================] - 0s 18ms/step
# files count:49, steering:0.5241866111755371
# 1/1 [==============================] - 0s 18ms/step
# files count:50, steering:0.47825008630752563
# 1/1 [==============================] - 0s 26ms/step
# files count:51, steering:0.5270888805389404
# 1/1 [==============================] - 0s 23ms/step
# files count:52, steering:0.4733504354953766
# 1/1 [==============================] - 0s 20ms/step
# files count:53, steering:0.49406978487968445
# 1/1 [==============================] - 0s 31ms/step
# files count:54, steering:0.5328249335289001
# 1/1 [==============================] - 0s 27ms/step
# files count:55, steering:0.5697738528251648
# 1/1 [==============================] - 0s 72ms/step
# files count:56, steering:0.5566807389259338
# 1/1 [==============================] - 0s 28ms/step
# files count:57, steering:0.5150350332260132
# 1/1 [==============================] - 0s 53ms/step
# files count:58, steering:0.5233649611473083
# 1/1 [==============================] - 0s 30ms/step
# files count:59, steering:0.5006838440895081
# 1/1 [==============================] - 0s 34ms/step
# files count:60, steering:0.5099474787712097
# 1/1 [==============================] - 0s 36ms/step
# files count:61, steering:0.49251264333724976
# 1/1 [==============================] - 0s 30ms/step
# files count:62, steering:0.5000641942024231
# 1/1 [==============================] - 0s 27ms/step
# files count:63, steering:0.490044504404068
# 1/1 [==============================] - 0s 27ms/step
# files count:64, steering:0.49069616198539734
# 1/1 [==============================] - 0s 23ms/step
# files count:65, steering:0.4837491810321808
# 1/1 [==============================] - 0s 18ms/step
# files count:66, steering:0.5014376640319824
# 1/1 [==============================] - 0s 32ms/step
# files count:67, steering:0.4819580316543579
# 1/1 [==============================] - 0s 27ms/step
# files count:68, steering:0.49148139357566833
# 1/1 [==============================] - 0s 31ms/step
# files count:69, steering:0.4755858778953552
# 1/1 [==============================] - 0s 39ms/step
# files count:70, steering:0.48097461462020874
# 1/1 [==============================] - 0s 30ms/step
# files count:71, steering:0.47319450974464417
# 1/1 [==============================] - 0s 33ms/step
# files count:72, steering:0.4599568247795105
# 1/1 [==============================] - 0s 31ms/step
# files count:73, steering:0.47995686531066895
# 1/1 [==============================] - 0s 26ms/step
# files count:74, steering:0.4679985046386719
# 1/1 [==============================] - 0s 27ms/step
# files count:75, steering:0.4616106152534485
# 1/1 [==============================] - 0s 25ms/step
# files count:76, steering:0.4638955295085907
# 1/1 [==============================] - 0s 22ms/step
# files count:77, steering:0.489300936460495
# 1/1 [==============================] - 0s 18ms/step
# files count:78, steering:0.5149917006492615
# 1/1 [==============================] - 0s 18ms/step
# files count:79, steering:0.4980892241001129
# 1/1 [==============================] - 0s 16ms/step
# files count:80, steering:0.5117236375808716
# 1/1 [==============================] - 0s 20ms/step
# files count:81, steering:0.5023365616798401
# 1/1 [==============================] - 0s 26ms/step
# files count:82, steering:0.49349939823150635
# 1/1 [==============================] - 0s 125ms/step
# files count:83, steering:0.5184058547019958
# 1/1 [==============================] - 0s 38ms/step
# files count:84, steering:0.4907815456390381
# 1/1 [==============================] - 0s 74ms/step
# files count:85, steering:0.46719685196876526
# 1/1 [==============================] - 0s 43ms/step
# files count:86, steering:0.48187074065208435
# 1/1 [==============================] - 0s 81ms/step
# files count:87, steering:0.4798869490623474
# 1/1 [==============================] - 0s 59ms/step
# files count:88, steering:0.4727807343006134
# 1/1 [==============================] - 0s 76ms/step
# files count:89, steering:0.46432241797447205
# 1/1 [==============================] - 0s 69ms/step
# files count:90, steering:0.45207592844963074
# 1/1 [==============================] - 0s 67ms/step
# files count:91, steering:0.462107390165329
# 1/1 [==============================] - 0s 54ms/step
# files count:92, steering:0.5152901411056519
# 1/1 [==============================] - 0s 19ms/step
# files count:93, steering:0.5456117987632751
# 1/1 [==============================] - 0s 18ms/step
# files count:94, steering:0.5094953775405884
# 1/1 [==============================] - 0s 17ms/step
# files count:95, steering:0.5191167593002319
# 1/1 [==============================] - 0s 19ms/step
# files count:96, steering:0.4930018484592438
# 1/1 [==============================] - 0s 28ms/step
# files count:97, steering:0.5688944458961487
# 1/1 [==============================] - 0s 28ms/step
# files count:98, steering:0.507986843585968
# 1/1 [==============================] - 0s 39ms/step
# files count:99, steering:0.48345431685447693
# 1/1 [==============================] - 0s 27ms/step
# files count:100, steering:0.5490887761116028
# 1/1 [==============================] - 0s 70ms/step
# files count:101, steering:0.49507761001586914
# 1/1 [==============================] - 0s 59ms/step
# files count:102, steering:0.4851538836956024
# 1/1 [==============================] - 0s 28ms/step
# files count:103, steering:0.5028719902038574
# 1/1 [==============================] - 0s 48ms/step
# files count:104, steering:0.5170934200286865
# 1/1 [==============================] - 0s 51ms/step
# files count:105, steering:0.4851049482822418
# 1/1 [==============================] - 0s 56ms/step
# files count:106, steering:0.5284950137138367
# 1/1 [==============================] - 0s 26ms/step
# files count:107, steering:0.5051952004432678
# 1/1 [==============================] - 0s 46ms/step
# files count:108, steering:0.5071194171905518
# 1/1 [==============================] - 0s 26ms/step
# files count:109, steering:0.49961036443710327
# 1/1 [==============================] - 0s 39ms/step
# files count:110, steering:0.49192923307418823
# 1/1 [==============================] - 0s 28ms/step
# files count:111, steering:0.4783245325088501
# 1/1 [==============================] - 0s 18ms/step
# files count:112, steering:0.49056148529052734
# 1/1 [==============================] - 0s 17ms/step
# files count:113, steering:0.4799736738204956
# 1/1 [==============================] - 0s 17ms/step
# files count:114, steering:0.4533337354660034
# 1/1 [==============================] - 0s 18ms/step
# files count:115, steering:0.47569629549980164
# 1/1 [==============================] - 0s 18ms/step
# files count:116, steering:0.4688737094402313
# 1/1 [==============================] - 0s 19ms/step
# files count:117, steering:0.4672483205795288
# 1/1 [==============================] - 0s 21ms/step
# files count:118, steering:0.474352091550827
# 1/1 [==============================] - 0s 23ms/step
# files count:119, steering:0.48687511682510376
# 1/1 [==============================] - 0s 19ms/step
# files count:120, steering:0.4913032650947571
# 1/1 [==============================] - 0s 18ms/step
# files count:121, steering:0.4988655745983124
# 1/1 [==============================] - 0s 19ms/step
# files count:122, steering:0.4742628037929535
# 1/1 [==============================] - 0s 17ms/step
# files count:123, steering:0.4712325930595398
# 1/1 [==============================] - 0s 19ms/step
# files count:124, steering:0.4562367796897888
# 1/1 [==============================] - 0s 18ms/step
# files count:125, steering:0.4632827937602997
# 1/1 [==============================] - 0s 18ms/step
# files count:126, steering:0.4591619670391083
# 1/1 [==============================] - 0s 18ms/step
# files count:127, steering:0.4467742145061493
# 1/1 [==============================] - 0s 25ms/step
# files count:128, steering:0.44916045665740967
# 1/1 [==============================] - 0s 22ms/step
# files count:129, steering:0.46316736936569214
# 1/1 [==============================] - 0s 19ms/step
# files count:130, steering:0.443807452917099
# 1/1 [==============================] - 0s 18ms/step
# files count:131, steering:0.45723462104797363
# 1/1 [==============================] - 0s 17ms/step
# files count:132, steering:0.47169435024261475
# 1/1 [==============================] - 0s 18ms/step
# files count:133, steering:0.43217405676841736
# 1/1 [==============================] - 0s 16ms/step
# files count:134, steering:0.452544242143631
# 1/1 [==============================] - 0s 18ms/step
# files count:135, steering:0.46833518147468567
# 1/1 [==============================] - 0s 16ms/step
# files count:136, steering:0.4247487485408783
# 1/1 [==============================] - 0s 26ms/step
# files count:137, steering:0.421182781457901
# 1/1 [==============================] - 0s 18ms/step
# files count:138, steering:0.44156527519226074
# 1/1 [==============================] - 0s 19ms/step
# files count:139, steering:0.45733213424682617
# 1/1 [==============================] - 0s 17ms/step
# files count:140, steering:0.40165096521377563
# 1/1 [==============================] - 0s 17ms/step
# files count:141, steering:0.46892237663269043
# 1/1 [==============================] - 0s 16ms/step
# files count:142, steering:0.44711169600486755
# 1/1 [==============================] - 0s 16ms/step
# files count:143, steering:0.40275973081588745
# 1/1 [==============================] - 0s 16ms/step
# files count:144, steering:0.452068030834198
# 1/1 [==============================] - 0s 17ms/step
# files count:145, steering:0.4848625957965851
# 1/1 [==============================] - 0s 25ms/step
# files count:146, steering:0.4375501871109009
# 1/1 [==============================] - 0s 19ms/step
# files count:147, steering:0.4237132668495178
# 1/1 [==============================] - 0s 22ms/step
# files count:148, steering:0.4956423342227936
# 1/1 [==============================] - 0s 17ms/step
# files count:149, steering:0.4552694261074066
# 1/1 [==============================] - 0s 27ms/step
# files count:150, steering:0.42296478152275085
# 1/1 [==============================] - 0s 33ms/step
# files count:151, steering:0.46694105863571167
# 1/1 [==============================] - 0s 26ms/step
# files count:152, steering:0.44541624188423157
# 1/1 [==============================] - 0s 26ms/step
# files count:153, steering:0.45185530185699463
# 1/1 [==============================] - 0s 26ms/step
# files count:154, steering:0.45203453302383423
# 1/1 [==============================] - 0s 25ms/step
# files count:155, steering:0.5264533758163452
# 1/1 [==============================] - 0s 28ms/step
# files count:156, steering:0.4614937901496887
# 1/1 [==============================] - 0s 26ms/step
# files count:157, steering:0.46765589714050293
# 1/1 [==============================] - 0s 28ms/step
# files count:158, steering:0.5350316166877747
# 1/1 [==============================] - 0s 24ms/step
# files count:159, steering:0.5070231556892395
# 1/1 [==============================] - 0s 24ms/step
# files count:160, steering:0.45799848437309265
# 1/1 [==============================] - 0s 26ms/step
# files count:161, steering:0.4832760989665985
# 1/1 [==============================] - 0s 24ms/step
# files count:162, steering:0.5372554659843445
# 1/1 [==============================] - 0s 25ms/step
# files count:163, steering:0.4763064682483673
# 1/1 [==============================] - 0s 24ms/step
# files count:164, steering:0.5000127553939819
# 1/1 [==============================] - 0s 25ms/step
# files count:165, steering:0.5721963047981262
# 1/1 [==============================] - 0s 25ms/step
# files count:166, steering:0.47583988308906555
# 1/1 [==============================] - 0s 25ms/step
# files count:167, steering:0.5280995965003967
# 1/1 [==============================] - 0s 25ms/step
# files count:168, steering:0.5382164716720581
# 1/1 [==============================] - 0s 25ms/step
# files count:169, steering:0.5004833936691284
# 1/1 [==============================] - 0s 24ms/step
# files count:170, steering:0.4769338071346283
# 1/1 [==============================] - 0s 34ms/step
# files count:171, steering:0.5054861903190613
# 1/1 [==============================] - 0s 24ms/step
# files count:172, steering:0.48540809750556946
# 1/1 [==============================] - 0s 31ms/step
# files count:173, steering:0.4750591516494751
# 1/1 [==============================] - 0s 28ms/step
# files count:174, steering:0.47124746441841125
# 1/1 [==============================] - 0s 25ms/step
# files count:175, steering:0.4858965277671814
# 1/1 [==============================] - 0s 32ms/step
# files count:176, steering:0.45925289392471313
# 1/1 [==============================] - 0s 29ms/step
# files count:177, steering:0.48028072714805603
# 1/1 [==============================] - 0s 26ms/step
# files count:178, steering:0.4872312545776367
# 1/1 [==============================] - 0s 36ms/step
# files count:179, steering:0.4502815306186676
# 1/1 [==============================] - 0s 24ms/step
# files count:180, steering:0.4817695617675781
# 1/1 [==============================] - 0s 26ms/step
# files count:181, steering:0.4804406464099884
# 1/1 [==============================] - 0s 29ms/step
# files count:182, steering:0.4351545572280884
# 1/1 [==============================] - 0s 24ms/step
# files count:183, steering:0.4570974111557007
# 1/1 [==============================] - 0s 20ms/step
# files count:184, steering:0.45466285943984985
# 1/1 [==============================] - 0s 17ms/step
# files count:185, steering:0.46432211995124817
# 1/1 [==============================] - 0s 20ms/step
# files count:186, steering:0.4880483150482178
# 1/1 [==============================] - 0s 17ms/step
# files count:187, steering:0.4830004870891571
# 1/1 [==============================] - 0s 20ms/step
# files count:188, steering:0.49042701721191406
# 1/1 [==============================] - 0s 21ms/step
# files count:189, steering:0.4598204791545868
# 1/1 [==============================] - 0s 18ms/step
# files count:190, steering:0.44224098324775696
# 1/1 [==============================] - 0s 19ms/step
# files count:191, steering:0.4887941777706146
# 1/1 [==============================] - 0s 19ms/step
# files count:192, steering:0.4255480468273163
# 1/1 [==============================] - 0s 20ms/step
# files count:193, steering:0.44877028465270996
# 1/1 [==============================] - 0s 19ms/step
# files count:194, steering:0.5247060060501099
# 1/1 [==============================] - 0s 19ms/step
# files count:195, steering:0.4541499614715576
# 1/1 [==============================] - 0s 24ms/step
# files count:196, steering:0.4660714864730835
# 1/1 [==============================] - 0s 22ms/step
# files count:197, steering:0.49916473031044006
# 1/1 [==============================] - 0s 25ms/step
# files count:198, steering:0.4422686696052551
# 1/1 [==============================] - 0s 25ms/step
# files count:199, steering:0.4634331166744232
# 1/1 [==============================] - 0s 23ms/step
# files count:200, steering:0.46993282437324524
# 1/1 [==============================] - 0s 24ms/step
# files count:201, steering:0.48982879519462585
# 1/1 [==============================] - 0s 26ms/step
# files count:202, steering:0.45815491676330566
# 1/1 [==============================] - 0s 23ms/step
# files count:203, steering:0.4878157675266266
# 1/1 [==============================] - 0s 24ms/step
# files count:204, steering:0.5663514137268066
# 1/1 [==============================] - 0s 25ms/step
# files count:205, steering:0.420924574136734
# 1/1 [==============================] - 0s 21ms/step
# files count:206, steering:0.4579993486404419
# 1/1 [==============================] - 0s 21ms/step
# files count:207, steering:0.520379364490509
# 1/1 [==============================] - 0s 24ms/step
# files count:208, steering:0.4678245186805725
# 1/1 [==============================] - 0s 23ms/step
# files count:209, steering:0.47074365615844727
# 1/1 [==============================] - 0s 21ms/step
# files count:210, steering:0.4891150891780853
# 1/1 [==============================] - 0s 23ms/step
# files count:211, steering:0.4641364812850952
# 1/1 [==============================] - 0s 26ms/step
# files count:212, steering:0.4538111984729767
# 1/1 [==============================] - 0s 23ms/step
# files count:213, steering:0.46119800209999084
# 1/1 [==============================] - 0s 24ms/step
# files count:214, steering:0.5322969555854797
# 1/1 [==============================] - 0s 24ms/step
# files count:215, steering:0.4100537896156311
# 1/1 [==============================] - 0s 22ms/step
# files count:216, steering:0.46625205874443054
# 1/1 [==============================] - 0s 22ms/step
# files count:217, steering:0.5065274238586426
# 1/1 [==============================] - 0s 21ms/step
# files count:218, steering:0.39446428418159485
# 1/1 [==============================] - 0s 23ms/step
# files count:219, steering:0.4494932293891907
# 1/1 [==============================] - 0s 32ms/step
# files count:220, steering:0.49770477414131165
# 1/1 [==============================] - 0s 22ms/step
# files count:221, steering:0.4380204975605011
# 1/1 [==============================] - 0s 22ms/step
# files count:222, steering:0.4306505620479584
# 1/1 [==============================] - 0s 21ms/step
# files count:223, steering:0.46111389994621277
# 1/1 [==============================] - 0s 21ms/step
# files count:224, steering:0.4404458701610565
# 1/1 [==============================] - 0s 27ms/step
# files count:225, steering:0.4115987718105316
# 1/1 [==============================] - 0s 21ms/step
# files count:226, steering:0.4938200116157532
# 1/1 [==============================] - 0s 23ms/step
# files count:227, steering:0.45220646262168884
# 1/1 [==============================] - 0s 24ms/step
# files count:228, steering:0.4348558783531189
# 1/1 [==============================] - 0s 23ms/step
# files count:229, steering:0.44809606671333313
# 1/1 [==============================] - 0s 21ms/step
# files count:230, steering:0.41561073064804077
# 1/1 [==============================] - 0s 22ms/step
# files count:231, steering:0.4193888306617737
# 1/1 [==============================] - 0s 20ms/step
# files count:232, steering:0.4245704114437103
# 1/1 [==============================] - 0s 28ms/step
# files count:233, steering:0.3998788297176361
# 1/1 [==============================] - 0s 24ms/step
# files count:234, steering:0.42829591035842896
# 1/1 [==============================] - 0s 21ms/step
# files count:235, steering:0.4355371594429016
# 1/1 [==============================] - 0s 22ms/step
# files count:236, steering:0.4163881242275238
# 1/1 [==============================] - 0s 20ms/step
# files count:237, steering:0.42254719138145447
# 1/1 [==============================] - 0s 20ms/step
# files count:238, steering:0.42906472086906433
# 1/1 [==============================] - 0s 23ms/step
# files count:239, steering:0.39320245385169983
# 1/1 [==============================] - 0s 21ms/step
# files count:240, steering:0.3806578814983368
# 1/1 [==============================] - 0s 21ms/step
# files count:241, steering:0.43243032693862915
# 1/1 [==============================] - 0s 20ms/step
# files count:242, steering:0.3458729386329651
# 1/1 [==============================] - 0s 23ms/step
# files count:243, steering:0.3762538433074951
# 1/1 [==============================] - 0s 26ms/step
# files count:244, steering:0.4054383933544159
# 1/1 [==============================] - 0s 23ms/step
# files count:245, steering:0.4065563678741455
# 1/1 [==============================] - 0s 22ms/step
# files count:246, steering:0.385382741689682
# 1/1 [==============================] - 0s 22ms/step
# files count:247, steering:0.39181700348854065
# 1/1 [==============================] - 0s 21ms/step
# files count:248, steering:0.4213523864746094
# 1/1 [==============================] - 0s 30ms/step
# files count:249, steering:0.35755082964897156
# 1/1 [==============================] - 0s 26ms/step
# files count:250, steering:0.3754258453845978
# 1/1 [==============================] - 0s 24ms/step
# files count:251, steering:0.4238673746585846
# 1/1 [==============================] - 0s 29ms/step
# files count:252, steering:0.3504975438117981
# 1/1 [==============================] - 0s 21ms/step
# files count:253, steering:0.351883202791214
# 1/1 [==============================] - 0s 29ms/step
# files count:254, steering:0.3982771039009094
# 1/1 [==============================] - 0s 21ms/step
# files count:255, steering:0.32945331931114197
# 1/1 [==============================] - 0s 25ms/step
# files count:256, steering:0.3402559161186218
# 1/1 [==============================] - 0s 22ms/step
# files count:257, steering:0.39923009276390076
# 1/1 [==============================] - 0s 22ms/step
# files count:258, steering:0.3773972690105438
# 1/1 [==============================] - 0s 21ms/step
# files count:259, steering:0.3392281234264374
# 1/1 [==============================] - 0s 23ms/step
# files count:260, steering:0.38429322838783264
# 1/1 [==============================] - 0s 22ms/step
# files count:261, steering:0.3791959583759308
# 1/1 [==============================] - 0s 22ms/step
# files count:262, steering:0.3264838457107544
# 1/1 [==============================] - 0s 23ms/step
# files count:263, steering:0.34932631254196167
# 1/1 [==============================] - 0s 21ms/step
# files count:264, steering:0.3658916652202606
# 1/1 [==============================] - 0s 24ms/step
# files count:265, steering:0.3185242712497711
# 1/1 [==============================] - 0s 21ms/step
# files count:266, steering:0.37584421038627625
# 1/1 [==============================] - 0s 27ms/step
# files count:267, steering:0.3642134368419647
# 1/1 [==============================] - 0s 21ms/step
# files count:268, steering:0.3556217551231384
# 1/1 [==============================] - 0s 24ms/step
# files count:269, steering:0.38807371258735657
# 1/1 [==============================] - 0s 22ms/step
# files count:270, steering:0.370132178068161
# 1/1 [==============================] - 0s 23ms/step
# files count:271, steering:0.3943468928337097
# 1/1 [==============================] - 0s 21ms/step
# files count:272, steering:0.39483460783958435
# 1/1 [==============================] - 0s 21ms/step
# files count:273, steering:0.3418726623058319
# 1/1 [==============================] - 0s 26ms/step
# files count:274, steering:0.4047812223434448
# 1/1 [==============================] - 0s 26ms/step
# files count:275, steering:0.32762300968170166
# 1/1 [==============================] - 0s 21ms/step
# files count:276, steering:0.3786775767803192
# 1/1 [==============================] - 0s 25ms/step
# files count:277, steering:0.35221096873283386
# 1/1 [==============================] - 0s 22ms/step
# files count:278, steering:0.3685443103313446
# 1/1 [==============================] - 0s 23ms/step
# files count:279, steering:0.39740273356437683
# 1/1 [==============================] - 0s 21ms/step
# files count:280, steering:0.36277318000793457
# 1/1 [==============================] - 0s 19ms/step
# files count:281, steering:0.39616966247558594
# 1/1 [==============================] - 0s 21ms/step
# files count:282, steering:0.41943734884262085
# 1/1 [==============================] - 0s 20ms/step
# files count:283, steering:0.3683248460292816
# 1/1 [==============================] - 0s 20ms/step
# files count:284, steering:0.4480527639389038
# 1/1 [==============================] - 0s 19ms/step
# files count:285, steering:0.4408188462257385
# 1/1 [==============================] - 0s 18ms/step
# files count:286, steering:0.404403954744339
# 1/1 [==============================] - 0s 18ms/step
# files count:287, steering:0.4277879297733307
# 1/1 [==============================] - 0s 18ms/step
# files count:288, steering:0.4626612067222595
# 1/1 [==============================] - 0s 20ms/step
# files count:289, steering:0.44745591282844543
# 1/1 [==============================] - 0s 20ms/step
# files count:290, steering:0.42855125665664673
# 1/1 [==============================] - 0s 20ms/step
# files count:291, steering:0.4902312457561493
# 1/1 [==============================] - 0s 19ms/step
# files count:292, steering:0.47702527046203613
# 1/1 [==============================] - 0s 19ms/step
# files count:293, steering:0.46329525113105774
# 1/1 [==============================] - 0s 18ms/step
# files count:294, steering:0.4633369743824005
# 1/1 [==============================] - 0s 19ms/step
# files count:295, steering:0.46538546681404114
# 1/1 [==============================] - 0s 18ms/step
# files count:296, steering:0.4126119613647461
# 1/1 [==============================] - 0s 19ms/step
# files count:297, steering:0.4573932886123657
# 1/1 [==============================] - 0s 18ms/step
# files count:298, steering:0.4683154821395874
# 1/1 [==============================] - 0s 18ms/step
# files count:299, steering:0.40896856784820557
# 1/1 [==============================] - 0s 20ms/step
# files count:300, steering:0.43100887537002563
# 1/1 [==============================] - 0s 19ms/step
# files count:301, steering:0.446829617023468
# 1/1 [==============================] - 0s 19ms/step
# files count:302, steering:0.44277849793434143
# 1/1 [==============================] - 0s 17ms/step
# files count:303, steering:0.4428618252277374
# 1/1 [==============================] - 0s 19ms/step
# files count:304, steering:0.48486950993537903
# 1/1 [==============================] - 0s 23ms/step
# files count:305, steering:0.46644866466522217
# 1/1 [==============================] - 0s 23ms/step
# files count:306, steering:0.46751219034194946
# 1/1 [==============================] - 0s 17ms/step
# files count:307, steering:0.49502378702163696
# 1/1 [==============================] - 0s 17ms/step
# files count:308, steering:0.5016576051712036
# 1/1 [==============================] - 0s 24ms/step
# files count:309, steering:0.4761808216571808
# 1/1 [==============================] - 0s 20ms/step
# files count:310, steering:0.5114970207214355
# 1/1 [==============================] - 0s 18ms/step
# files count:311, steering:0.5078644752502441
# 1/1 [==============================] - 0s 16ms/step
# files count:312, steering:0.46590152382850647
# 1/1 [==============================] - 0s 23ms/step
# files count:313, steering:0.4871542453765869
# 1/1 [==============================] - 0s 19ms/step
# files count:314, steering:0.5161439180374146
# 1/1 [==============================] - 0s 20ms/step
# files count:315, steering:0.4868960976600647
# 1/1 [==============================] - 0s 22ms/step
# files count:316, steering:0.4754156172275543
# 1/1 [==============================] - 0s 18ms/step
# files count:317, steering:0.5109277367591858
# 1/1 [==============================] - 0s 17ms/step
# files count:318, steering:0.5255972146987915
# 1/1 [==============================] - 0s 16ms/step
# files count:319, steering:0.5002192258834839
# 1/1 [==============================] - 0s 19ms/step
# files count:320, steering:0.513361394405365
# 1/1 [==============================] - 0s 20ms/step
# files count:321, steering:0.5060881972312927
# 1/1 [==============================] - 0s 18ms/step
# files count:322, steering:0.49902138113975525
# 1/1 [==============================] - 0s 18ms/step
# files count:323, steering:0.5265167951583862
# 1/1 [==============================] - 0s 23ms/step
# files count:324, steering:0.5064267516136169
# 1/1 [==============================] - 0s 18ms/step
# files count:325, steering:0.46733155846595764
# 1/1 [==============================] - 0s 17ms/step
# files count:326, steering:0.47938287258148193
# 1/1 [==============================] - 0s 20ms/step
# files count:327, steering:0.5128107666969299
# 1/1 [==============================] - 0s 19ms/step
# files count:328, steering:0.4742182195186615
# 1/1 [==============================] - 0s 22ms/step
# files count:329, steering:0.4673252999782562
# 1/1 [==============================] - 0s 19ms/step
# files count:330, steering:0.49593308568000793
# 1/1 [==============================] - 0s 18ms/step
# files count:331, steering:0.4692741334438324
# 1/1 [==============================] - 0s 19ms/step
# files count:332, steering:0.4736674427986145
# 1/1 [==============================] - 0s 24ms/step
# files count:333, steering:0.48828068375587463
# 1/1 [==============================] - 0s 19ms/step
# files count:334, steering:0.47138160467147827
# 1/1 [==============================] - 0s 17ms/step
# files count:335, steering:0.48275431990623474
# 1/1 [==============================] - 0s 18ms/step
# files count:336, steering:0.48995324969291687
# 1/1 [==============================] - 0s 27ms/step
# files count:337, steering:0.4370311498641968
# 1/1 [==============================] - 0s 18ms/step
# files count:338, steering:0.48341044783592224
# 1/1 [==============================] - 0s 17ms/step
# files count:339, steering:0.4626207649707794
# 1/1 [==============================] - 0s 18ms/step
# files count:340, steering:0.4474846124649048
# 1/1 [==============================] - 0s 23ms/step
# files count:341, steering:0.43892762064933777
# 1/1 [==============================] - 0s 26ms/step
# files count:342, steering:0.44476205110549927
# 1/1 [==============================] - 0s 26ms/step
# files count:343, steering:0.4316141605377197
# 1/1 [==============================] - 0s 27ms/step
# files count:344, steering:0.4220218360424042
# 1/1 [==============================] - 0s 31ms/step
# files count:345, steering:0.45089027285575867
# 1/1 [==============================] - 0s 25ms/step
# files count:346, steering:0.4366760849952698
# 1/1 [==============================] - 0s 24ms/step
# files count:347, steering:0.4287751317024231
# 1/1 [==============================] - 0s 24ms/step
# files count:348, steering:0.45578354597091675
# 1/1 [==============================] - 0s 25ms/step
# files count:349, steering:0.3996332585811615
# 1/1 [==============================] - 0s 24ms/step
# files count:350, steering:0.4245740473270416
# 1/1 [==============================] - 0s 27ms/step
# files count:351, steering:0.4141760468482971
# 1/1 [==============================] - 0s 27ms/step
# files count:352, steering:0.43250954151153564
# 1/1 [==============================] - 0s 28ms/step
# files count:353, steering:0.40770986676216125
# 1/1 [==============================] - 0s 27ms/step
# files count:354, steering:0.41605108976364136
# 1/1 [==============================] - 0s 24ms/step
# files count:355, steering:0.47165560722351074
# 1/1 [==============================] - 0s 27ms/step
# files count:356, steering:0.40637561678886414
# 1/1 [==============================] - 0s 30ms/step
# files count:357, steering:0.44153836369514465
# 1/1 [==============================] - 0s 25ms/step
# files count:358, steering:0.4148341715335846
# 1/1 [==============================] - 0s 24ms/step
# files count:359, steering:0.43972715735435486
# 1/1 [==============================] - 0s 31ms/step
# files count:360, steering:0.4132429361343384
# 1/1 [==============================] - 0s 26ms/step
# files count:361, steering:0.4087832570075989
# 1/1 [==============================] - 0s 26ms/step
# files count:362, steering:0.3738878071308136
# 1/1 [==============================] - 0s 26ms/step
# files count:363, steering:0.3985946476459503
# 1/1 [==============================] - 0s 25ms/step
# files count:364, steering:0.38153275847435
# 1/1 [==============================] - 0s 29ms/step
# files count:365, steering:0.43702706694602966
# 1/1 [==============================] - 0s 24ms/step
# files count:366, steering:0.4027160704135895
# 1/1 [==============================] - 0s 26ms/step
# files count:367, steering:0.3983393609523773
# 1/1 [==============================] - 0s 28ms/step
# files count:368, steering:0.45822858810424805
# 1/1 [==============================] - 0s 27ms/step
# files count:369, steering:0.41881394386291504
# 1/1 [==============================] - 0s 27ms/step
# files count:370, steering:0.4269581139087677
# 1/1 [==============================] - 0s 30ms/step
# files count:371, steering:0.4606057107448578
# 1/1 [==============================] - 0s 26ms/step
# files count:372, steering:0.4675246477127075
# 1/1 [==============================] - 0s 26ms/step
# files count:373, steering:0.4042474329471588
# 1/1 [==============================] - 0s 25ms/step
# files count:374, steering:0.4499579966068268
# 1/1 [==============================] - 0s 25ms/step
# files count:375, steering:0.4283946454524994
# 1/1 [==============================] - 0s 21ms/step
# files count:376, steering:0.45099082589149475
# 1/1 [==============================] - 0s 19ms/step
# files count:377, steering:0.47654077410697937
# 1/1 [==============================] - 0s 17ms/step
# files count:378, steering:0.4734470546245575
# 1/1 [==============================] - 0s 18ms/step
# files count:379, steering:0.4355872571468353
# 1/1 [==============================] - 0s 18ms/step
# files count:380, steering:0.44804736971855164
# 1/1 [==============================] - 0s 18ms/step
# files count:381, steering:0.42405304312705994
# 1/1 [==============================] - 0s 19ms/step
# files count:382, steering:0.4130505919456482
# 1/1 [==============================] - 0s 19ms/step
# files count:383, steering:0.4351126253604889
# 1/1 [==============================] - 0s 21ms/step
# files count:384, steering:0.4453698396682739
# 1/1 [==============================] - 0s 18ms/step
# files count:385, steering:0.4155326187610626
# 1/1 [==============================] - 0s 24ms/step
# files count:386, steering:0.4226004183292389
# 1/1 [==============================] - 0s 18ms/step
# files count:387, steering:0.43127456307411194
# 1/1 [==============================] - 0s 16ms/step
# files count:388, steering:0.42358243465423584
# 1/1 [==============================] - 0s 21ms/step
# files count:389, steering:0.42110010981559753
# 1/1 [==============================] - 0s 19ms/step
# files count:390, steering:0.4633783996105194
# 1/1 [==============================] - 0s 18ms/step
# files count:391, steering:0.4169631898403168
# 1/1 [==============================] - 0s 20ms/step
# files count:392, steering:0.4229282736778259
# 1/1 [==============================] - 0s 17ms/step
# files count:393, steering:0.3961132764816284
# 1/1 [==============================] - 0s 17ms/step
# files count:394, steering:0.4470290541648865
# 1/1 [==============================] - 0s 16ms/step
# files count:395, steering:0.40364113450050354
# 1/1 [==============================] - 0s 17ms/step
# files count:396, steering:0.4211388826370239
# 1/1 [==============================] - 0s 17ms/step
# files count:397, steering:0.44771355390548706
# 1/1 [==============================] - 0s 19ms/step
# files count:398, steering:0.41014447808265686
# 1/1 [==============================] - 0s 16ms/step
# files count:399, steering:0.4127161204814911
# 1/1 [==============================] - 0s 17ms/step
# files count:400, steering:0.4398704767227173
# 1/1 [==============================] - 0s 18ms/step
# files count:401, steering:0.4353708326816559
# 1/1 [==============================] - 0s 17ms/step
# files count:402, steering:0.40131911635398865
# 1/1 [==============================] - 0s 20ms/step
# files count:403, steering:0.4712390899658203
# 1/1 [==============================] - 0s 18ms/step
# files count:404, steering:0.42486920952796936
# 1/1 [==============================] - 0s 22ms/step
# files count:405, steering:0.43209466338157654
# 1/1 [==============================] - 0s 20ms/step
# files count:406, steering:0.42270874977111816
# 1/1 [==============================] - 0s 22ms/step
# files count:407, steering:0.461505651473999
# 1/1 [==============================] - 0s 17ms/step
# files count:408, steering:0.4084317088127136
# 1/1 [==============================] - 0s 20ms/step
# files count:409, steering:0.44025731086730957
# 1/1 [==============================] - 0s 23ms/step
# files count:410, steering:0.47619661688804626
# 1/1 [==============================] - 0s 25ms/step
# files count:411, steering:0.435049831867218
# 1/1 [==============================] - 0s 17ms/step
# files count:412, steering:0.4351280927658081
# 1/1 [==============================] - 0s 28ms/step
# files count:413, steering:0.4322221875190735
# 1/1 [==============================] - 0s 16ms/step
# files count:414, steering:0.42742887139320374
# 1/1 [==============================] - 0s 17ms/step
# files count:415, steering:0.4032650291919708
# 1/1 [==============================] - 0s 18ms/step
# files count:416, steering:0.4463682174682617
# 1/1 [==============================] - 0s 17ms/step
# files count:417, steering:0.3949684202671051
# 1/1 [==============================] - 0s 17ms/step
# files count:418, steering:0.43180862069129944
# 1/1 [==============================] - 0s 18ms/step
# files count:419, steering:0.3961256444454193
# 1/1 [==============================] - 0s 20ms/step
# files count:420, steering:0.4250657558441162
# 1/1 [==============================] - 0s 17ms/step
# files count:421, steering:0.41697221994400024
# 1/1 [==============================] - 0s 24ms/step
# files count:422, steering:0.41895830631256104
# 1/1 [==============================] - 0s 16ms/step
# files count:423, steering:0.41290098428726196
# 1/1 [==============================] - 0s 18ms/step
# files count:424, steering:0.4130886197090149
# 1/1 [==============================] - 0s 17ms/step
# files count:425, steering:0.3624868094921112
# 1/1 [==============================] - 0s 20ms/step
# files count:426, steering:0.3832305371761322
# 1/1 [==============================] - 0s 16ms/step
# files count:427, steering:0.4064249098300934
# 1/1 [==============================] - 0s 17ms/step
# files count:428, steering:0.3598054051399231
# 1/1 [==============================] - 0s 17ms/step
# files count:429, steering:0.35858479142189026
# 1/1 [==============================] - 0s 18ms/step
# files count:430, steering:0.28467825055122375
# 1/1 [==============================] - 0s 18ms/step
# files count:431, steering:0.37956589460372925
# 1/1 [==============================] - 0s 23ms/step
# files count:432, steering:0.3758292496204376
# 1/1 [==============================] - 0s 22ms/step
# files count:433, steering:0.4013744592666626
# 1/1 [==============================] - 0s 22ms/step
# files count:434, steering:0.4157242178916931
# 1/1 [==============================] - 0s 20ms/step
# files count:435, steering:0.37560805678367615
# 1/1 [==============================] - 0s 19ms/step
# files count:436, steering:0.45285800099372864
# 1/1 [==============================] - 0s 23ms/step
# files count:437, steering:0.427883118391037
# 1/1 [==============================] - 0s 20ms/step
# files count:438, steering:0.4090002477169037
# 1/1 [==============================] - 0s 22ms/step
# files count:439, steering:0.46336767077445984
# 1/1 [==============================] - 0s 20ms/step
# files count:440, steering:0.4686562716960907
# 1/1 [==============================] - 0s 22ms/step
# files count:441, steering:0.46113288402557373
# 1/1 [==============================] - 0s 18ms/step
# files count:442, steering:0.522352933883667
# 1/1 [==============================] - 0s 17ms/step
# files count:443, steering:0.4095706343650818
# 1/1 [==============================] - 0s 17ms/step
# files count:444, steering:0.4757642149925232
# 1/1 [==============================] - 0s 17ms/step
# files count:445, steering:0.4931240379810333
# 1/1 [==============================] - 0s 17ms/step
# files count:446, steering:0.484554648399353
# 1/1 [==============================] - 0s 16ms/step
# files count:447, steering:0.45336148142814636
# 1/1 [==============================] - 0s 18ms/step
# files count:448, steering:0.4636540412902832
# 1/1 [==============================] - 0s 18ms/step
# files count:449, steering:0.4953746199607849
# 1/1 [==============================] - 0s 17ms/step
# files count:450, steering:0.42447543144226074
# 1/1 [==============================] - 0s 19ms/step
# files count:451, steering:0.5092996954917908
# 1/1 [==============================] - 0s 18ms/step
# files count:452, steering:0.5018113851547241
# 1/1 [==============================] - 0s 17ms/step
# files count:453, steering:0.48954230546951294
# 1/1 [==============================] - 0s 17ms/step
# files count:454, steering:0.5171560049057007
# 1/1 [==============================] - 0s 17ms/step
# files count:455, steering:0.5112230181694031
# 1/1 [==============================] - 0s 16ms/step
# files count:456, steering:0.4502849280834198
# 1/1 [==============================] - 0s 19ms/step
# files count:457, steering:0.5337169766426086
# 1/1 [==============================] - 0s 25ms/step
# files count:458, steering:0.5612127780914307
# 1/1 [==============================] - 0s 33ms/step
# files count:459, steering:0.4309742748737335
# 1/1 [==============================] - 0s 18ms/step
# files count:460, steering:0.5020349621772766
# 1/1 [==============================] - 0s 18ms/step
# files count:461, steering:0.585466206073761
# 1/1 [==============================] - 0s 18ms/step
# files count:462, steering:0.6316972374916077
# 1/1 [==============================] - 0s 18ms/step
# files count:463, steering:0.6425493955612183
# 1/1 [==============================] - 0s 20ms/step
# files count:464, steering:0.695809543132782
# 1/1 [==============================] - 0s 18ms/step
# files count:465, steering:0.49080684781074524
# 1/1 [==============================] - 0s 17ms/step
# files count:466, steering:0.6997413039207458
# 1/1 [==============================] - 0s 19ms/step
# files count:467, steering:0.6871820688247681
# 1/1 [==============================] - 0s 17ms/step
# files count:468, steering:0.48137417435646057
# 1/1 [==============================] - 0s 16ms/step
# files count:469, steering:0.813869059085846
# 1/1 [==============================] - 0s 18ms/step
# files count:470, steering:0.8199117183685303
# 1/1 [==============================] - 0s 20ms/step
# files count:471, steering:0.9258999228477478
# 1/1 [==============================] - 0s 29ms/step
# files count:472, steering:0.8145613670349121
# 1/1 [==============================] - 0s 18ms/step
# files count:473, steering:0.7703057527542114
# 1/1 [==============================] - 0s 17ms/step
# files count:474, steering:0.7888712286949158
# 1/1 [==============================] - 0s 17ms/step
# files count:475, steering:0.8995636105537415
# 1/1 [==============================] - 0s 18ms/step
# files count:476, steering:0.7117743492126465
# 1/1 [==============================] - 0s 18ms/step
# files count:477, steering:0.45883965492248535
# 1/1 [==============================] - 0s 19ms/step
# files count:478, steering:0.7675422430038452
# 1/1 [==============================] - 0s 19ms/step
# files count:479, steering:0.624386727809906
# 1/1 [==============================] - 0s 18ms/step
# files count:480, steering:0.5368865728378296
# 1/1 [==============================] - 0s 17ms/step
# files count:481, steering:0.41606229543685913
# 1/1 [==============================] - 0s 17ms/step
# files count:482, steering:0.557524561882019
# 1/1 [==============================] - 0s 16ms/step
# files count:483, steering:0.46326935291290283
# 1/1 [==============================] - 0s 17ms/step
# files count:484, steering:0.8913872838020325
# 1/1 [==============================] - 0s 24ms/step
# files count:485, steering:0.6239666938781738
# 1/1 [==============================] - 0s 19ms/step
# files count:486, steering:0.4151751399040222
# 1/1 [==============================] - 0s 18ms/step
# files count:487, steering:0.4474925398826599
# 1/1 [==============================] - 0s 25ms/step
# files count:488, steering:0.5970502495765686
# 1/1 [==============================] - 0s 18ms/step
# files count:489, steering:0.287645161151886
# 1/1 [==============================] - 0s 18ms/step
# files count:490, steering:0.22007989883422852
# 1/1 [==============================] - 0s 16ms/step
# files count:491, steering:0.4088142514228821
# 1/1 [==============================] - 0s 16ms/step
# files count:492, steering:0.2775931656360626
# 1/1 [==============================] - 0s 17ms/step
# files count:493, steering:0.31307363510131836
# 1/1 [==============================] - 0s 19ms/step
# files count:494, steering:0.34402400255203247
# 1/1 [==============================] - 0s 19ms/step
# files count:495, steering:0.3756118416786194
# 1/1 [==============================] - 0s 19ms/step
# files count:496, steering:0.419301301240921
# 1/1 [==============================] - 0s 18ms/step
# files count:497, steering:0.7289304137229919
# 1/1 [==============================] - 0s 17ms/step
# files count:498, steering:0.36911070346832275
# 1/1 [==============================] - 0s 17ms/step
# files count:499, steering:0.521605372428894
# 1/1 [==============================] - 0s 18ms/step
# files count:500, steering:0.5692667961120605
# <ipython-input-71-448749b4a60f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vgg16_df["VGG16_PredDeg"] = vgg16_df["Image"].apply(predict_image)

# %%
df1 = pd.read_csv('/content/NVIDIA_DS2PRED3.csv')
df2 = pd.read_csv('/content/VGG16-DS2PRED3.csv')
df3 = pd.DataFrame(df2['Image'],
                   columns=['Image'],
                   index=None)
df3['NVIDIA_PredDeg'] = df1['NVIDIA_PredDeg']
df3['VGG16_PredDeg'] =df2['VGG16_PredDeg']
timestamp = np.arange(len(df3)) * 0.2
df3['Timestamp'] = timestamp
df3.to_csv('ds2_comparision.csv',index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# corner_check = pd.read_csv('RUN1-VGG16_170.csv')
steering_nvidia = df3['NVIDIA_PredDeg'] 
timestamps = df3["Timestamp"]
steering_vgg16 = df3['VGG16_PredDeg']

def show_nvidia():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_nvidia, color='darkblue', label='Actual')
    # ax.plot(timestamps, steering_prediction, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp')

    ax.set_ylabel('NVDIA Steering Angle(degrees)')
    ax.set_title('NVDIA Steering Angle')
    plt.show()


def show_vgg16():
    fig, ax = plt.subplots()
    ax.plot(timestamps, steering_vgg16, color='darkOrange', label='Prediction')
    ax.legend()
    ax.set_xlabel('Timestamp')
    ax.set_ylabel('VGG16 Steering Angle(degrees)')
    ax.set_title('VGG16 Steering Angle')
    plt.show()

# show_prediction()

# %%
show_nvidia()

# %%
show_vgg16()
